# %%
import os

def rename_files_in_folder(folder_path, prefix):
    # List all files in the folder
    files = os.listdir(folder_path)
    # Sort files to ensure sequential naming
    files.sort()
    # Loop through the files and rename them
    for i, filename in enumerate(files):
        # Construct new name with sequential number
        new_name = f"{prefix}{i + 1}{os.path.splitext(filename)[1]}"
        # Get full path for the current and new filename
        src = os.path.join(folder_path, filename)
        dst = os.path.join(folder_path, new_name)
        # Rename the file
        os.rename(src, dst)
    print(f"Renamed {len(files)} files in folder: {folder_path}")

def main(directory):
    # Define folder names
    folders = ['cats', 'panda', 'dogs']
    for folder in folders:
        # Construct the full path to each folder
        folder_path = os.path.join(directory, folder)
        if os.path.exists(folder_path):
            # Rename files in the folder
            rename_files_in_folder(folder_path, folder[:-1])
        else:
            print(f"Folder not found: {folder_path}")

if __name__ == "__main__":
    # Use a raw string to avoid unicode escape issues
    main(r'C:\Users\LAPTOPINN\Downloads\ANIMALS')
# Out:
# Renamed 1000 files in folder: C:\Users\LAPTOPINN\Downloads\ANIMALS\cats
# Renamed 1000 files in folder: C:\Users\LAPTOPINN\Downloads\ANIMALS\panda
# Renamed 1000 files in folder: C:\Users\LAPTOPINN\Downloads\ANIMALS\dogs

# %% [markdown]
# ## DATA SET
#
# This Python script automates the renaming of files within specific subfolders of an image dataset directory. Here's a breakdown of the script's functionality and the structure of the dataset:
#
# ### Script Functionality
# - The script defines a function `rename_files_in_folder()` to sequentially rename files within a given folder. It sorts files to ensure sequential naming and renames each file by appending a sequential number to a prefix.
# - The `main()` function orchestrates the renaming process for multiple subfolders within a directory. It iterates through predefined folder names ('cats', 'panda', 'dogs'), constructs the full path to each folder, and calls `rename_files_in_folder()` for renaming.
# - The script execution block ensures that the `main()` function is called when the script is run directly.
#
# ### Dataset Structure
# - The dataset directory specified in the script contains three subfolders: 'cats', 'panda', and 'dogs'.
# - Each subfolder represents a distinct class of images corresponding to a specific animal category.
# - The dataset is well-organized, with over 1000 images in each subfolder, ensuring a sufficient amount of data for training or analysis tasks.
#
# ### Usage
# To use this script:
# 1. Specify the directory containing the image dataset.
# 2. Ensure that the dataset directory structure matches the expected structure (i.e., subfolders for each animal category).
# 3. Run the script, which will automatically rename all files within the subfolders according to their category and a sequential number.
#
# This automated renaming process enhances dataset organization and facilitates subsequent data processing tasks, such as training machine learning models or conducting image analysis.

# %%
import os
import cv2
import numpy as np
import random
from collections import Counter

# Function to augment an image
def augment_image(image):
    # Rotate image
    angle = random.randint(-30, 30)
    M = cv2.getRotationMatrix2D((image.shape[1]//2, image.shape[0]//2), angle, 1)
    rotated = cv2.warpAffine(image, M, (image.shape[1], image.shape[0]))

    # Flip image
    flipped = cv2.flip(rotated, 1)

    # Scale image
    scale = random.uniform(0.8, 1.2)
    scaled = cv2.resize(flipped, None, fx=scale, fy=scale, interpolation=cv2.INTER_LINEAR)
    
    return scaled

# Function to preprocess an image
def preprocess_image(image):
    # Convert image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Normalize image
    normalized = cv2.normalize(gray, None, 0, 255, cv2.NORM_MINMAX)

    # Histogram equalization
    equalized = cv2.equalizeHist(normalized)

    # Denoising
    denoised = cv2.fastNlMeansDenoising(equalized, None, 30, 7, 21)

    return denoised

# Function to load, augment, and preprocess images
def load_and_prepare_images(folder):
    images = []
    labels = []
    counter=0
    for class_name in os.listdir(folder):
        class_path = os.path.join(folder, class_name)
        if os.path.isdir(class_path):
            for img_name in os.listdir(class_path):
                img_path = os.path.join(class_path, img_name)
                img = cv2.imread(img_path)
                if img is not None:
                    # Augment and preprocess image
                    augmented_img = augment_image(img)
                    preprocessed_img = preprocess_image(augmented_img)
                    images.append(preprocessed_img)
                    labels.append(class_name)
                    counter += 1
                    if counter % 50 == 0:
                        print(f"{counter} done")
    return images, labels

# Define the dataset folder path
dataset_folder = r'C:\Users\LAPTOPINN\Downloads\ANIMALS'

# Load, augment, and preprocess dataset
images, labels = load_and_prepare_images(dataset_folder)

# Convert lists to numpy arrays for compatibility with further processing
images = np.array(images)
labels = np.array(labels)

# Print class distribution
class_distribution = Counter(labels)
print("Class distribution:", class_distribution)

# Example to show shape of images and labels
print("Images shape:", images.shape)
print("Labels shape:", labels.shape)
# Out:
# 50 done
# 100 done
# 150 done
# 200 done
# 250 done
# 300 done
# 350 done
# 400 done
# 450 done
# 500 done
# 550 done
# 600 done
# 650 done
# 700 done
# 750 done
# 800 done
# 850 done
# 900 done
# 950 done
# 1000 done
# 1050 done
# 1100 done
# 1150 done
# 1200 done
# 1250 done
# 1300 done
# 1350 done
# 1400 done
# 1450 done
# 1500 done
# 1550 done
# 1600 done
# 1650 done
# 1700 done
# 1750 done
# 1800 done
# 1850 done
# 1900 done
# 1950 done
# 2000 done
# 2050 done
# 2100 done
# 2150 done
# 2200 done
# 2250 done
# 2300 done
# 2350 done
# 2400 done
# 2450 done
# 2500 done
# 2550 done
# 2600 done
# 2650 done
# 2700 done
# 2750 done
# 2800 done
# 2850 done
# 2900 done
# 2950 done
# 3000 done
# Class distribution: Counter({'cats': 1000, 'dogs': 1000, 'panda': 1000})
# Images shape: (3000,)
# Labels shape: (3000,)
# C:\Temp\ipykernel_19028\2341095280.py:68: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   images = np.array(images)

# %% [markdown]
# ### AUGMENTING AND PREPROCESSING
# This Python script efficiently handles image processing tasks, from loading and augmenting images to preprocessing them for further analysis. Leveraging OpenCV and NumPy libraries, it streamlines the transformation of raw image data into a format suitable for machine learning or computer vision applications.
#
# The script employs functions like augment_image() and preprocess_image() to introduce variability and standardize images, respectively. It systematically processes images from specified folders using load_and_prepare_images(), logging progress as it progresses through each image.
#
# After processing, it converts image and label lists into NumPy arrays and analyzes class distribution using the Counter module. This structured approach lays a strong foundation for image-based tasks, facilitating efficient dataset preparation and analysis for subsequent modeling endeavors.

# %%
import os
import cv2

# Function to compute HOG features for an image
def compute_hog_features(image):
    # Convert image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Resize image to reduce dimensionality
    resized_image = cv2.resize(gray, (64, 128))  # Adjust size as needed
    
    # Initialize HOG descriptor
    hog = cv2.HOGDescriptor()
    
    # Compute HOG features
    features = hog.compute(resized_image)
    
    return features.flatten()  # Flatten the feature vector

# Function to compute HOG features for all images in a folder
def compute_hog_features_in_folder(folder_path):
    hog_features_list = []
    for filename in os.listdir(folder_path):
        # Load image
        image_path = os.path.join(folder_path, filename)
        image = cv2.imread(image_path)
        if image is not None:
            # Compute HOG features
            hog_features = compute_hog_features(image)
            hog_features_list.append(hog_features)
    return hog_features_list

# Path to the folder containing subfolders with images
dataset_folder = r'C:\Users\LAPTOPINN\Downloads\ANIMALS'

# List of subfolder names
subfolders = ['cats', 'dogs', 'panda']

# Iterate over each subfolder
for subfolder in subfolders:
    print(f"Computing HOG features for images in '{subfolder}' folder:")
    
    # Path to the current subfolder
    subfolder_path = os.path.join(dataset_folder, subfolder)
    
    # Compute HOG features for all images in the current subfolder
    hog_features_list = compute_hog_features_in_folder(subfolder_path)
    
    # Print the number of images and their corresponding HOG features
    print(f"Number of images: {len(hog_features_list)}")
    for i, hog_features in enumerate(hog_features_list):
        print(f"Image {i+1}: HOG Features Shape: {hog_features.shape}")
# Out:
# Computing HOG features for images in 'cats' folder:
# Number of images: 1000
# Image 1: HOG Features Shape: (3780,)
# Image 2: HOG Features Shape: (3780,)
# Image 3: HOG Features Shape: (3780,)
# Image 4: HOG Features Shape: (3780,)
# Image 5: HOG Features Shape: (3780,)
# Image 6: HOG Features Shape: (3780,)
# Image 7: HOG Features Shape: (3780,)
# Image 8: HOG Features Shape: (3780,)
# Image 9: HOG Features Shape: (3780,)
# Image 10: HOG Features Shape: (3780,)
# Image 11: HOG Features Shape: (3780,)
# Image 12: HOG Features Shape: (3780,)
# Image 13: HOG Features Shape: (3780,)
# Image 14: HOG Features Shape: (3780,)
# Image 15: HOG Features Shape: (3780,)
# Image 16: HOG Features Shape: (3780,)
# Image 17: HOG Features Shape: (3780,)
# Image 18: HOG Features Shape: (3780,)
# Image 19: HOG Features Shape: (3780,)
# Image 20: HOG Features Shape: (3780,)
# Image 21: HOG Features Shape: (3780,)
# Image 22: HOG Features Shape: (3780,)
# Image 23: HOG Features Shape: (3780,)
# Image 24: HOG Features Shape: (3780,)
# Image 25: HOG Features Shape: (3780,)
# Image 26: HOG Features Shape: (3780,)
# Image 27: HOG Features Shape: (3780,)
# Image 28: HOG Features Shape: (3780,)
# Image 29: HOG Features Shape: (3780,)
# Image 30: HOG Features Shape: (3780,)
# Image 31: HOG Features Shape: (3780,)
# Image 32: HOG Features Shape: (3780,)
# Image 33: HOG Features Shape: (3780,)
# Image 34: HOG Features Shape: (3780,)
# Image 35: HOG Features Shape: (3780,)
# Image 36: HOG Features Shape: (3780,)
# Image 37: HOG Features Shape: (3780,)
# Image 38: HOG Features Shape: (3780,)
# Image 39: HOG Features Shape: (3780,)
# Image 40: HOG Features Shape: (3780,)
# Image 41: HOG Features Shape: (3780,)
# Image 42: HOG Features Shape: (3780,)
# Image 43: HOG Features Shape: (3780,)
# Image 44: HOG Features Shape: (3780,)
# Image 45: HOG Features Shape: (3780,)
# Image 46: HOG Features Shape: (3780,)
# Image 47: HOG Features Shape: (3780,)
# Image 48: HOG Features Shape: (3780,)
# Image 49: HOG Features Shape: (3780,)
# Image 50: HOG Features Shape: (3780,)
# Image 933: HOG Features Shape: (3780,)
# Image 934: HOG Features Shape: (3780,)
# Image 935: HOG Features Shape: (3780,)
# Image 936: HOG Features Shape: (3780,)
# Image 937: HOG Features Shape: (3780,)
# Image 938: HOG Features Shape: (3780,)
# Image 939: HOG Features Shape: (3780,)
# Image 940: HOG Features Shape: (3780,)
# Image 941: HOG Features Shape: (3780,)
# Image 942: HOG Features Shape: (3780,)
# Image 943: HOG Features Shape: (3780,)
# Image 944: HOG Features Shape: (3780,)
# Image 945: HOG Features Shape: (3780,)
# Image 946: HOG Features Shape: (3780,)
# Image 947: HOG Features Shape: (3780,)
# Image 948: HOG Features Shape: (3780,)
# Image 949: HOG Features Shape: (3780,)
# Image 950: HOG Features Shape: (3780,)
# Image 951: HOG Features Shape: (3780,)
# Image 952: HOG Features Shape: (3780,)
# Image 953: HOG Features Shape: (3780,)
# Image 954: HOG Features Shape: (3780,)
# Image 955: HOG Features Shape: (3780,)
# Image 956: HOG Features Shape: (3780,)
# Image 957: HOG Features Shape: (3780,)
# Image 958: HOG Features Shape: (3780,)
# Image 959: HOG Features Shape: (3780,)
# Image 960: HOG Features Shape: (3780,)
# Image 961: HOG Features Shape: (3780,)
# Image 962: HOG Features Shape: (3780,)
# Image 963: HOG Features Shape: (3780,)
# Image 964: HOG Features Shape: (3780,)
# Image 965: HOG Features Shape: (3780,)
# Image 966: HOG Features Shape: (3780,)
# Image 967: HOG Features Shape: (3780,)
# Image 968: HOG Features Shape: (3780,)
# Image 969: HOG Features Shape: (3780,)
# Image 970: HOG Features Shape: (3780,)
# Image 971: HOG Features Shape: (3780,)
# Image 972: HOG Features Shape: (3780,)
# Image 973: HOG Features Shape: (3780,)
# Image 974: HOG Features Shape: (3780,)
# Image 975: HOG Features Shape: (3780,)
# Image 976: HOG Features Shape: (3780,)
# Image 977: HOG Features Shape: (3780,)
# Image 978: HOG Features Shape: (3780,)
# Image 979: HOG Features Shape: (3780,)
# Image 980: HOG Features Shape: (3780,)
# Image 981: HOG Features Shape: (3780,)
# Image 982: HOG Features Shape: (3780,)
# Image 983: HOG Features Shape: (3780,)
# Image 984: HOG Features Shape: (3780,)
# Image 985: HOG Features Shape: (3780,)
# Image 986: HOG Features Shape: (3780,)
# Image 987: HOG Features Shape: (3780,)
# Image 988: HOG Features Shape: (3780,)
# Image 989: HOG Features Shape: (3780,)
# Image 990: HOG Features Shape: (3780,)
# Image 991: HOG Features Shape: (3780,)
# Image 992: HOG Features Shape: (3780,)
# Image 993: HOG Features Shape: (3780,)
# Image 994: HOG Features Shape: (3780,)
# Image 995: HOG Features Shape: (3780,)
# Image 996: HOG Features Shape: (3780,)
# Image 997: HOG Features Shape: (3780,)
# Image 998: HOG Features Shape: (3780,)
# Image 999: HOG Features Shape: (3780,)
# Image 1000: HOG Features Shape: (3780,)

# %% [markdown]
# ### HOG
# This script is designed to extract Histogram of Oriented Gradient (HOG) features from an input image using Python's OpenCV library. At its core is the compute_hog_features() function, which processes the image through a series of steps. Initially, it converts the image to grayscale to simplify subsequent calculations. Then, it initializes a HOG descriptor and computes the HOG features for the grayscale image. Finally, the resulting feature vector is flattened to ensure compatibility with further processing.
#
# In the main execution block, an example image is loaded from a specified file path using cv2.imread(). This image is then passed to the compute_hog_features() function to extract its HOG features. The shape of the resulting feature vector is printed, providing insight into the dimensionality of the extracted features.
#
# This script serves as a foundational tool for extracting descriptive features from images, which is essential for various computer vision tasks such as object detection, recognition, and classification.

# %%
import os
import tensorflow as tf
import numpy as np

# Load the pre-trained VGG16 model
model = tf.keras.applications.VGG16(weights='imagenet', include_top=False)

# Function to extract high-level CNN features from an image
def extract_high_level_cnn_features(image_path, layer_name='block5_pool'):
    # Load and preprocess the image
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = tf.keras.applications.vgg16.preprocess_input(img_array)
    
    # Extract features from the specified layer
    intermediate_model = tf.keras.Model(inputs=model.input, outputs=model.get_layer(layer_name).output)
    features = intermediate_model.predict(img_array)
    
    return features.flatten()  # Flatten the feature vector

# Function to extract high-level CNN features for all images in a folder
def extract_high_level_cnn_features_in_folder(folder_path, layer_name='block5_pool'):
    cnn_features_list = []
    for filename in os.listdir(folder_path):
        # Load image
        image_path = os.path.join(folder_path, filename)
        # Extract high-level CNN features for the image
        cnn_features = extract_high_level_cnn_features(image_path, layer_name)
        cnn_features_list.append(cnn_features)
    return cnn_features_list

# Path to the folder containing subfolders with images
dataset_folder = r'C:\Users\LAPTOPINN\Downloads\ANIMALS'

# List of subfolder names
subfolders = ['cats', 'dogs', 'panda']

# Specify the layer from which to extract features
layer_name = 'block5_pool'

# Dictionary to store high-level CNN features for each subfolder
all_cnn_features = {}

# Iterate over each subfolder
for subfolder in subfolders:
    print(f"Extracting high-level CNN features for images in '{subfolder}' folder:")
    
    # Path to the current subfolder
    subfolder_path = os.path.join(dataset_folder, subfolder)
    
    # Extract high-level CNN features for all images in the current subfolder
    cnn_features_list = extract_high_level_cnn_features_in_folder(subfolder_path, layer_name)
    
    # Store the features in the dictionary
    all_cnn_features[subfolder] = cnn_features_list

    # Print the number of images and their corresponding high-level CNN features
    print(f"Number of images: {len(cnn_features_list)}")
    for i, cnn_features in enumerate(cnn_features_list):
        print(f"Image {i+1}: High-Level CNN Features Shape: {cnn_features.shape}")

# Print the dictionary containing high-level CNN features for all subfolders
print("\nHigh-Level CNN Features for All Subfolders:")
print(all_cnn_features)
# Out:
# Extracting high-level CNN features for images in 'cats' folder:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001DEC27605E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 911ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001DEC2760C10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 683ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 574ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# Number of images: 1000
# Image 1: High-Level CNN Features Shape: (25088,)
# Image 2: High-Level CNN Features Shape: (25088,)
# Image 3: High-Level CNN Features Shape: (25088,)
# Image 4: High-Level CNN Features Shape: (25088,)
# Image 5: High-Level CNN Features Shape: (25088,)
# Image 6: High-Level CNN Features Shape: (25088,)
# Image 7: High-Level CNN Features Shape: (25088,)
# Image 8: High-Level CNN Features Shape: (25088,)
# Image 9: High-Level CNN Features Shape: (25088,)
# Image 10: High-Level CNN Features Shape: (25088,)
# Image 11: High-Level CNN Features Shape: (25088,)
# Image 12: High-Level CNN Features Shape: (25088,)
# Image 13: High-Level CNN Features Shape: (25088,)
# Image 14: High-Level CNN Features Shape: (25088,)
# Image 15: High-Level CNN Features Shape: (25088,)
# Image 16: High-Level CNN Features Shape: (25088,)
# Image 17: High-Level CNN Features Shape: (25088,)
# Image 18: High-Level CNN Features Shape: (25088,)
# Image 19: High-Level CNN Features Shape: (25088,)
# Image 20: High-Level CNN Features Shape: (25088,)
# Image 21: High-Level CNN Features Shape: (25088,)
# Image 22: High-Level CNN Features Shape: (25088,)
# Image 23: High-Level CNN Features Shape: (25088,)
# Image 24: High-Level CNN Features Shape: (25088,)
# Image 25: High-Level CNN Features Shape: (25088,)
# Image 26: High-Level CNN Features Shape: (25088,)
# Image 27: High-Level CNN Features Shape: (25088,)
# Image 28: High-Level CNN Features Shape: (25088,)
# Image 29: High-Level CNN Features Shape: (25088,)
# Image 30: High-Level CNN Features Shape: (25088,)
# Image 31: High-Level CNN Features Shape: (25088,)
# Image 32: High-Level CNN Features Shape: (25088,)
# Image 33: High-Level CNN Features Shape: (25088,)
# Image 34: High-Level CNN Features Shape: (25088,)
# Image 35: High-Level CNN Features Shape: (25088,)
# Image 36: High-Level CNN Features Shape: (25088,)
# Image 37: High-Level CNN Features Shape: (25088,)
# Image 38: High-Level CNN Features Shape: (25088,)
# Image 39: High-Level CNN Features Shape: (25088,)
# Image 40: High-Level CNN Features Shape: (25088,)
# Image 41: High-Level CNN Features Shape: (25088,)
# Image 42: High-Level CNN Features Shape: (25088,)
# Image 43: High-Level CNN Features Shape: (25088,)
# Image 44: High-Level CNN Features Shape: (25088,)
# Image 45: High-Level CNN Features Shape: (25088,)
# Image 46: High-Level CNN Features Shape: (25088,)
# Image 47: High-Level CNN Features Shape: (25088,)
# Image 48: High-Level CNN Features Shape: (25088,)
# Image 49: High-Level CNN Features Shape: (25088,)
# Image 50: High-Level CNN Features Shape: (25088,)
# Image 51: High-Level CNN Features Shape: (25088,)
# Image 52: High-Level CNN Features Shape: (25088,)
# Image 53: High-Level CNN Features Shape: (25088,)
# Image 54: High-Level CNN Features Shape: (25088,)
# Image 55: High-Level CNN Features Shape: (25088,)
# Image 56: High-Level CNN Features Shape: (25088,)
# Image 57: High-Level CNN Features Shape: (25088,)
# Image 58: High-Level CNN Features Shape: (25088,)
# Image 59: High-Level CNN Features Shape: (25088,)
# Image 60: High-Level CNN Features Shape: (25088,)
# Image 61: High-Level CNN Features Shape: (25088,)
# Image 62: High-Level CNN Features Shape: (25088,)
# Image 63: High-Level CNN Features Shape: (25088,)
# Image 64: High-Level CNN Features Shape: (25088,)
# Image 65: High-Level CNN Features Shape: (25088,)
# Image 66: High-Level CNN Features Shape: (25088,)
# Image 67: High-Level CNN Features Shape: (25088,)
# Image 68: High-Level CNN Features Shape: (25088,)
# Image 69: High-Level CNN Features Shape: (25088,)
# Image 70: High-Level CNN Features Shape: (25088,)
# Image 71: High-Level CNN Features Shape: (25088,)
# Image 72: High-Level CNN Features Shape: (25088,)
# Image 73: High-Level CNN Features Shape: (25088,)
# Image 74: High-Level CNN Features Shape: (25088,)
# Image 75: High-Level CNN Features Shape: (25088,)
# Image 76: High-Level CNN Features Shape: (25088,)
# Image 77: High-Level CNN Features Shape: (25088,)
# Image 78: High-Level CNN Features Shape: (25088,)
# Image 79: High-Level CNN Features Shape: (25088,)
# Image 80: High-Level CNN Features Shape: (25088,)
# Image 81: High-Level CNN Features Shape: (25088,)
# Image 82: High-Level CNN Features Shape: (25088,)
# Image 83: High-Level CNN Features Shape: (25088,)
# Image 84: High-Level CNN Features Shape: (25088,)
# Image 85: High-Level CNN Features Shape: (25088,)
# Image 86: High-Level CNN Features Shape: (25088,)
# Image 87: High-Level CNN Features Shape: (25088,)
# Image 88: High-Level CNN Features Shape: (25088,)
# Image 89: High-Level CNN Features Shape: (25088,)
# Image 90: High-Level CNN Features Shape: (25088,)
# Image 91: High-Level CNN Features Shape: (25088,)
# Image 92: High-Level CNN Features Shape: (25088,)
# Image 93: High-Level CNN Features Shape: (25088,)
# Image 94: High-Level CNN Features Shape: (25088,)
# Image 95: High-Level CNN Features Shape: (25088,)
# Image 96: High-Level CNN Features Shape: (25088,)
# Image 97: High-Level CNN Features Shape: (25088,)
# Image 98: High-Level CNN Features Shape: (25088,)
# Image 99: High-Level CNN Features Shape: (25088,)
# Image 100: High-Level CNN Features Shape: (25088,)
# Image 101: High-Level CNN Features Shape: (25088,)
# Image 102: High-Level CNN Features Shape: (25088,)
# Image 103: High-Level CNN Features Shape: (25088,)
# Image 104: High-Level CNN Features Shape: (25088,)
# Image 105: High-Level CNN Features Shape: (25088,)
# Image 106: High-Level CNN Features Shape: (25088,)
# Image 107: High-Level CNN Features Shape: (25088,)
# Image 108: High-Level CNN Features Shape: (25088,)
# Image 109: High-Level CNN Features Shape: (25088,)
# Image 110: High-Level CNN Features Shape: (25088,)
# Image 111: High-Level CNN Features Shape: (25088,)
# Image 112: High-Level CNN Features Shape: (25088,)
# Image 113: High-Level CNN Features Shape: (25088,)
# Image 114: High-Level CNN Features Shape: (25088,)
# Image 115: High-Level CNN Features Shape: (25088,)
# Image 116: High-Level CNN Features Shape: (25088,)
# Image 117: High-Level CNN Features Shape: (25088,)
# Image 118: High-Level CNN Features Shape: (25088,)
# Image 119: High-Level CNN Features Shape: (25088,)
# Image 120: High-Level CNN Features Shape: (25088,)
# Image 121: High-Level CNN Features Shape: (25088,)
# Image 122: High-Level CNN Features Shape: (25088,)
# Image 123: High-Level CNN Features Shape: (25088,)
# Image 124: High-Level CNN Features Shape: (25088,)
# Image 125: High-Level CNN Features Shape: (25088,)
# Image 126: High-Level CNN Features Shape: (25088,)
# Image 127: High-Level CNN Features Shape: (25088,)
# Image 128: High-Level CNN Features Shape: (25088,)
# Image 129: High-Level CNN Features Shape: (25088,)
# Image 130: High-Level CNN Features Shape: (25088,)
# Image 131: High-Level CNN Features Shape: (25088,)
# Image 132: High-Level CNN Features Shape: (25088,)
# Image 133: High-Level CNN Features Shape: (25088,)
# Image 134: High-Level CNN Features Shape: (25088,)
# Image 135: High-Level CNN Features Shape: (25088,)
# Image 136: High-Level CNN Features Shape: (25088,)
# Image 137: High-Level CNN Features Shape: (25088,)
# Image 138: High-Level CNN Features Shape: (25088,)
# Image 139: High-Level CNN Features Shape: (25088,)
# Image 140: High-Level CNN Features Shape: (25088,)
# Image 141: High-Level CNN Features Shape: (25088,)
# Image 142: High-Level CNN Features Shape: (25088,)
# Image 143: High-Level CNN Features Shape: (25088,)
# Image 144: High-Level CNN Features Shape: (25088,)
# Image 145: High-Level CNN Features Shape: (25088,)
# Image 146: High-Level CNN Features Shape: (25088,)
# Image 147: High-Level CNN Features Shape: (25088,)
# Image 148: High-Level CNN Features Shape: (25088,)
# ...
#         0.      ], dtype=float32), array([0.      , 0.      , 0.      , ..., 9.153732, 0.      , 0.      ],
#       dtype=float32), array([ 0.     ,  0.     ,  0.     , ...,  0.     , 26.91908,  0.     ],
#       dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#        3.0330012], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 3.691528, 0.      ],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.      ,  0.      ,  0.      , ...,  0.      ,  0.      ,
#        11.339071], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 1.0770681,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.      ,  0.      ,  0.      , ...,  0.      , 19.043049,
#         0.      ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 7.1355643,
#        0.       ], dtype=float32), array([0.      , 0.      , 8.569861, ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([42.709515  ,  0.        ,  0.35069317, ...,  0.        ,
#         6.959061  ,  0.        ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.      ,  0.      ,  0.      , ..., 58.000042,  0.      ,
#         0.      ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 3.936241, 0.      ],
#       dtype=float32), array([ 0.      ,  0.      ,  0.      , ...,  0.      , 11.255604,
#         0.      ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 5.970126, 0.      ],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 2.8023632,
#        0.       ], dtype=float32), array([ 0.      ,  0.      ,  0.      , ...,  0.      , 15.354495,
#         0.      ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.9758832, 0.       ,
#        0.       ], dtype=float32), array([ 0.     ,  0.     , 80.96704, ...,  0.     ,  0.     ,  0.     ],
#       dtype=float32), array([9.072188, 0.      , 0.      , ..., 0.      , 5.877121, 0.      ],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.      ,  0.      ,  0.      , ..., 12.761022,  0.      ,
#         0.      ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 1.3888829, 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 8.363062 ,
#        3.4240415], dtype=float32), array([ 0.      , 25.417355,  0.      , ...,  0.      ,  0.      ,
#         0.      ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([32.05152 , 17.017502, 21.99956 , ...,  5.74908 ,  0.      ,
#         0.      ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.      ,  0.      ,  0.      , ...,  0.      , 28.485023,
#         0.      ], dtype=float32), array([10.680526,  0.      ,  0.      , ...,  0.      ,  0.      ,
#         0.      ], dtype=float32), array([ 0.      ,  0.      ,  0.      , ...,  0.      , 13.067081,
#         0.      ], dtype=float32), array([ 0.      ,  0.      ,  0.      , ...,  0.      , 18.104668,
#         0.      ], dtype=float32), array([ 0.      ,  0.      , 12.279373, ...,  0.      ,  0.      ,
#         0.      ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 6.070104, 0.      ],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 5.335355, 27.741905, 19.634384, ...,  0.      ,  9.695147,
#         0.      ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 3.1808183,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 8.665312, 0.      ],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 0.       ,
#        4.2935247], dtype=float32), array([19.174976,  0.      ,  0.      , ...,  0.      ,  0.      ,
#         0.      ], dtype=float32), array([6.122484 , 0.       , 0.5922379, ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([4.3634624, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([ 0.     ,  0.     ,  0.     , ...,  0.     , 42.13108,  0.     ],
#       dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 2.7099373,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 1.334027, 0.      ],
#       dtype=float32), array([ 0.      ,  0.      ,  0.      , ..., 41.50721 ,  7.104682,
#         0.      ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.       ,  0.       ,  0.       , ...,  0.       , 12.8252125,
#         0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.      ,  0.      , 13.450269, ...,  0.      , 15.21776 ,
#         0.      ], dtype=float32), array([ 0.97396684,  0.        ,  0.        , ...,  0.        ,
#        13.861596  , 34.78842   ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.      , 16.099657,  0.      , ...,  0.      ,  0.      ,
#         0.      ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 0.      , 8.571963],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.     ,  0.     , 52.12804, ...,  0.     ,  0.     ,  0.     ],
#       dtype=float32), array([ 9.341543,  0.      , 25.530767, ...,  0.      ,  0.      ,
#         0.      ], dtype=float32), array([ 0.      ,  0.      ,  0.      , ...,  0.      , 12.138194,
#        25.212933], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 8.318286, 0.      ],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 4.167697, 0.      ],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 0.      , 4.510268],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 0.      , 4.254177],
#       dtype=float32), array([0.       , 0.       , 2.1434216, ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.      , 5.300198, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.7017193,  0.       , 15.304598 , ...,  0.       ,  0.       ,
#         0.       ], dtype=float32), array([12.489317,  0.      ,  0.      , ...,  0.      , 12.930852,
#         0.      ], dtype=float32), array([0.      , 0.      , 0.      , ..., 4.906627, 0.      , 0.      ],
#       dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 1.4768646,
#        0.       ], dtype=float32), array([0.      , 0.      , 4.440924, ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([ 0.      ,  0.      ,  0.      , ...,  0.      , 19.100437,
#         0.      ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.      ,  0.      , 11.567348, ...,  0.      ,  0.      ,
#         0.      ], dtype=float32), array([0.      , 0.      , 0.      , ..., 9.417905, 0.      , 0.      ],
#       dtype=float32), array([ 5.733592 ,  1.1977642, 18.669546 , ...,  0.       ,  2.0174973,
#        12.590719 ], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 0.      , 7.353044],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.      , 0.      , 3.092709, ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([14.348747,  0.      , 41.19206 , ...,  0.      ,  0.      ,
#         0.      ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 5.3768497,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.       ,  0.       , 12.713818 , ..., 14.8324585,  0.       ,
#         0.       ], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 9.404606, 0.      ],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.      , 12.483897,  0.      , ...,  0.      ,  0.      ,
#         0.      ], dtype=float32), array([0.3860631, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.      , 2.304651, 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([101.69789 ,   0.      ,   7.416861, ...,   0.      ,   0.      ,
#          0.      ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.       ,  0.       ,  0.       , ...,  0.       , 13.1691265,
#         0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.     ,  0.     ,  0.     , ...,  0.     , 33.17809,  0.     ],
#       dtype=float32), array([1.6789496, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 3.9169133,
#        0.       ], dtype=float32), array([ 0.      ,  0.      , 33.18793 , ...,  0.      ,  0.      ,
#         8.574258], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.      ,  0.      ,  0.      , ...,  0.      ,  0.      ,
#        37.791977], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.      , 20.312723,  0.      , ...,  0.      ,  0.      ,
#         0.      ], dtype=float32), array([ 0.       ,  0.       ,  7.6804385, ...,  0.       , 21.038126 ,
#         0.       ], dtype=float32), array([ 0.      ,  0.      ,  0.      , ...,  0.      , 14.883019,
#         0.      ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 1.4316733,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.      ,  0.      , 14.391559, ...,  0.      ,  0.      ,
#         0.      ], dtype=float32), array([ 0.       ,  0.       ,  1.8436189, ...,  0.       ,  4.1313853,
#        11.036422 ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 2.2499979,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([3.8559582, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 2.225846, 0.      ],
#       dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 5.0786567,
#        0.       ], dtype=float32), array([0.       , 0.       , 0.       , ..., 0.       , 1.5181777,
#        0.       ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([23.411055,  0.      ,  0.      , ...,  0.      ,  6.514089,
#         0.      ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 9.217007, 0.      ],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.     , 0.     , 0.     , ..., 0.     , 6.91165, 0.     ],
#       dtype=float32), array([ 0.      ,  0.      ,  0.      , ...,  0.      ,  0.      ,
#        16.287214], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 1.8042538,  0.       , 43.019287 , ...,  0.       , 11.529324 ,
#         0.       ], dtype=float32), array([ 0.      ,  0.      ,  0.      , ...,  0.      ,  0.      ,
#        24.338337], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.      , 10.564284,  0.      , ...,  9.542382, 21.62892 ,
#         0.      ], dtype=float32), array([ 7.78333 ,  0.      ,  0.      , ...,  0.      , 15.177813,
#         0.      ], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0.      , 0.      , 0.      , ..., 0.      , 6.314959, 0.      ],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([ 0.     , 21.13516,  0.     , ...,  0.     ,  0.     ,  0.     ],
#       dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), array([3.220084, 0.      , 0.      , ..., 0.      , 0.      , 0.      ],
#       dtype=float32), array([35.609406,  0.      , 38.952984, ...,  0.      ,  0.      ,
#         0.      ], dtype=float32)]}

# %% [markdown]
# ### CNN USING VGG16 FROM TENSORFLOW AND KERAS API
# This script utilizes TensorFlow and Keras to extract deep Convolutional Neural Network (CNN) features from an input image, leveraging the pre-trained VGG16 model. Here's a concise overview:
#
# The VGG16 model, pre-trained on the ImageNet dataset, is loaded via TensorFlow's Keras applications module. This model serves as a powerful feature extractor, capable of recognizing a broad spectrum of visual features.
#
# The `extract_deep_cnn_features()` function is then defined to process an input image, ensuring it aligns with VGG16's input requirements. It loads, resizes, converts, and preprocesses the image, before passing it through the VGG16 model to extract deep CNN features.
#
# In the main execution block, an example image's path is specified, and the `extract_deep_cnn_features()` function is called to compute the CNN features. The resulting feature vector's shape is printed, offering insights into its dimensionality.
#
# ### Comparing HOG and deep CNN features:
# - HOG features excel in capturing local gradient orientation, making them suitable for simpler tasks like object detection and tracking.
# - Deep CNN features, as learned from hierarchical representations, offer rich semantic information, making them superior for complex tasks like image classification and recognition.
#
# In this scenario, deep CNN features from VGG16 typically outperform HOG features, particularly for tasks demanding high-level image understanding. However, the choice depends on specific task requirements, including computational efficiency and interpretability.

# %%
import os
import cv2
import numpy as np
import random
import tensorflow as tf
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# Step 1: Data Preparation with OpenCV and NumPy
def load_and_prepare_images(folder):
    images = []
    labels = []
    for class_name in os.listdir(folder):
        class_path = os.path.join(folder, class_name)
        if os.path.isdir(class_path):
            for img_name in os.listdir(class_path):
                img_path = os.path.join(class_path, img_name)
                img = cv2.imread(img_path)
                if img is not None:
                    # Apply augmentation techniques (rotate, flip, scale)
                    img = augment_image(img)
                    # Apply preprocessing techniques (normalize, histogram equalization, denoising)
                    img = preprocess_image(img)
                    images.append(img)
                    labels.append(class_name)
    return images, labels

def augment_image(image):
    # Rotate image
    angle = random.randint(-30, 30)
    M = cv2.getRotationMatrix2D((image.shape[1]//2, image.shape[0]//2), angle, 1)
    rotated = cv2.warpAffine(image, M, (image.shape[1], image.shape[0]))
    # Flip image
    flipped = cv2.flip(rotated, 1)
    # Scale image
    scale = random.uniform(0.8, 1.2)
    scaled = cv2.resize(flipped, None, fx=scale, fy=scale, interpolation=cv2.INTER_LINEAR)
    return scaled

def preprocess_image(image):
    # Skip grayscale and normalization for images fed into VGG16 model
    # Apply histogram equalization and denoising if necessary, but ensure the image stays 3-channel
    image = cv2.cvtColor(image, cv2.COLOR_BGR2YCrCb)
    channels = cv2.split(image)
    cv2.equalizeHist(channels[0], channels[0])
    image = cv2.merge(channels)
    image = cv2.cvtColor(image, cv2.COLOR_YCrCb2BGR)
    # Denoising
    denoised = cv2.fastNlMeansDenoisingColored(image, None, 30, 7, 21)
    return denoised

# Step 2: Feature Extraction with TensorFlow's Keras API
def extract_deep_cnn_features(images):
    model = tf.keras.applications.VGG16(weights='imagenet', include_top=False)
    features = []
    for img in images:
        img = cv2.resize(img, (224, 224))  # Resize image to VGG16 input size
        img_array = tf.keras.preprocessing.image.img_to_array(img)  # Convert image to array
        img_array = np.expand_dims(img_array, axis=0)  # Expand dimensions to create batch
        img_array = tf.keras.applications.vgg16.preprocess_input(img_array)  # Preprocess input (e.g., normalization)
        # Extract features using pre-trained VGG16 model
        features.append(model.predict(img_array).flatten())
    return features

# Step 3: Dimensionality Reduction with NumPy and scikit-learn
def perform_pca(features, n_components):
    pca = PCA(n_components=n_components)
    reduced_features = pca.fit_transform(features)
    return reduced_features, pca

# Step 4: Classification using SVM with scikit-learn
def train_svm(features, labels):
    # Split data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)
    
    # Train SVM classifier
    svm = SVC(kernel='linear')  # Use linear kernel
    svm.fit(X_train, y_train)
    
    # Predict on test set
    y_pred = svm.predict(X_test)
    
    # Evaluate performance
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    
    return svm

# Load and prepare training images
dataset_folder = r'D:\ANIMALS'
print("PREPROCESSING TRAINING IMAGES")
images, labels = load_and_prepare_images(dataset_folder)

# Extract deep CNN features
print("EXTRACTING DEEP FEATURES FROM TRAINING IMAGES")
deep_features = extract_deep_cnn_features(images)

# Perform PCA for dimensionality reduction
n_components = 60
print("REDUCING FEATURES OF TRAINING IMAGES")
reduced_features, pca = perform_pca(deep_features, n_components)

# Train SVM classifier
print("TRAINING SVM ON TRAINING IMAGES")
svm_classifier = train_svm(reduced_features, labels)

# Function to load and preprocess test images
def load_and_prepare_test_images(folder):
    images = []
    image_names = []
    for img_name in os.listdir(folder):
        img_path = os.path.join(folder, img_name)
        img = cv2.imread(img_path)
        if img is not None:
            # Preprocess image (without augmentation for test set)
            img = preprocess_image(img)
            images.append(img)
            image_names.append(img_name)
    return images, image_names

# Load and prepare test images
test_folder = r'D:\ANIMALS TEST'
print("PREPROCESSING TESTING IMAGES")
test_images, test_image_names = load_and_prepare_test_images(test_folder)

# Extract deep CNN features for test images
print("EXTRACTING FEATURES OF TESTING IMAGES")
test_features = extract_deep_cnn_features(test_images)

# Apply PCA transformation to test features
print("REDUCING FEATURES OF TESTING IMAGES")
reduced_test_features = pca.transform(test_features)

# Predict test images using the trained SVM classifier
print("PREDICTING TESTING IMAGES")
predicted_labels = svm_classifier.predict(reduced_test_features)

# Print the test results
print()
for img_name, label in zip(test_image_names, predicted_labels):
    print(f"Image: {img_name}, Predicted Label: {label}")
# Out:
# PREPROCESSING TRAINING IMAGES
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 95
#      93 dataset_folder = r'D:\ANIMALS'
#      94 print("PREPROCESSING TRAINING IMAGES")
# ---> 95 images, labels = load_and_prepare_images(dataset_folder)
#      97 # Extract deep CNN features
#      98 print("EXTRACTING DEEP FEATURES FROM TRAINING IMAGES")
#
# Cell In[13], line 26, in load_and_prepare_images(folder)
#      24 img = augment_image(img)
#      25 # Apply preprocessing techniques (normalize, histogram equalization, denoising)
# ---> 26 img = preprocess_image(img)
#      27 images.append(img)
#      28 labels.append(class_name)
#
# Cell In[13], line 52, in preprocess_image(image)
#      50 image = cv2.cvtColor(image, cv2.COLOR_YCrCb2BGR)
#      51 # Denoising
# ---> 52 denoised = cv2.fastNlMeansDenoisingColored(image, None, 30, 7, 21)
#      53 return denoised
#
# KeyboardInterrupt:

# %% [markdown]
# ## Image Classification Pipeline Using SVM with Deep Features
#
# This Python script outlines a comprehensive pipeline for image classification using Support Vector Machine (SVM) with deep features extracted from a pre-trained VGG16 model. The steps involved in this pipeline are:
#
# ### 1. Data Preparation
# - Utilizing OpenCV and NumPy, the script loads and prepares training images from a specified dataset folder. Augmentation techniques such as rotation, flipping, and scaling are applied alongside preprocessing techniques like histogram equalization and denoising.
#
# ### 2. Feature Extraction
# - TensorFlow's Keras API is employed to extract deep CNN features from the preprocessed images using the pre-trained VGG16 model. These features serve as informative representations of the image content.
#
# ### 3. Dimensionality Reduction
# - The extracted deep features are subjected to Principal Component Analysis (PCA) using scikit-learn to reduce their dimensionality while retaining essential information. This step enhances computational efficiency and mitigates the curse of dimensionality.
#
# ### 4. Training SVM Classifier
# - The reduced features are split into training and testing sets. A linear Support Vector Machine (SVM) classifier is trained on the training set, leveraging scikit-learn's SVM implementation. The model is then evaluated using the test set, providing insights into its classification performance.
#
# ### 5. Testing and Prediction
# - The script further prepares test images from a separate folder, applying the same preprocessing steps. Deep CNN features are extracted and dimensionality-reduced using the previously trained PCA model. The trained SVM classifier predicts the labels of the test images, facilitating evaluation and inference.
#
# ### Conclusion
# - This image classification pipeline showcases the integration of deep learning-based feature extraction with traditional machine learning techniques like SVM. By leveraging the power of deep features and SVM, the pipeline offers a robust solution for image classification tasks, demonstrating the synergy between deep learning and classical machine learning approaches.
